# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client= genai.client()
    interaction = client.interaction.creat (
        model="gemini=3.5-flash",
        input="天空為什麼是藍的"
    )
print (interaction)
# Out:
#   Cell In[15], line 7
#     interaction = client.interaction.creat (
#     ^
# IndentationError: unexpected indent
