# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以呈現藍色，主要是因為一個物理現象，叫做**「瑞利散射」（Rayleigh scattering）**。
#
# 這可以拆解為以下三個步驟來理解：
#
# ### 1. 太陽光其實是「彩虹色」的
# 雖然太陽光看起來是白色的，但它其實包含了紅、橙、黃、綠、藍、靛、紫等所有顏色的光。這些光以「波」的形式傳播：
# *   **紅光、橙光**：波長較**長**。
# *   **藍光、紫光**：波長較**短**。
#
# ### 2. 大氣層的「擋路」粒子
# 當太陽光穿過地球的大氣層時，會遇到大氣中的氣體分子（主要是氮氣和氧氣）。這些分子的尺寸非常小，比光的波長還要小。
#
# ### 3. 關鍵的「瑞利散射」
# 當光線碰到這些微小的氣體分子時，就會產生散射（往四面八方彈射）。
# 根據物理規律，**波長較短的光（藍光、紫光）被散射的能力，比波長較長的光（紅光）強了約 10 倍**。
# 因此，藍色光在進入大氣層後，被空氣分子撞得四處亂飛，充滿了整個天空。當我們抬頭看天空時，這些被散射的藍色光進入了我們的眼睛，所以天空看起來就是藍色的。
#
# ---
#
# ### 常見疑問：為什麼天空不是「紫色」的？
# 既然紫光的波長比藍光更短，被散射得更厲害，那為什麼天空不是紫色的？原因有兩個：
#
# 1.  **太陽光的成分**：太陽放射出的光芒中，藍光的比例本來就比紫光多很多。
# 2.  **人類眼睛的構造**：人類眼睛對藍色比較敏感，對紫色的感光能力較差。因此，我們的眼睛和和大腦合作「過濾」後，看到的主要是藍色。
#
# ### 補充：那為什麼夕陽是紅色的？
# 黃昏或日出時，太陽角度很低，陽光必須穿過**非常厚**的大氣層才能到達我們的眼睛。
# 在這個過程中，大部分的藍光在半路就已經被散射光了，根本無法到達我們的眼睛。只有波長最長、穿透力最強的**紅光和橙光**能夠穿透厚厚的大氣層，所以夕陽看起來就是紅澄澄的。
