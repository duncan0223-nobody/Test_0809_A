# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以是藍色的，主要是因為**太陽光**、**地球大氣層**以及**人類眼睛的感光特性**這三個因素共同作用的結果。
#
# 這個物理現象被稱為**「瑞利散射」（Rayleigh scattering）**。以下為您用簡單的步驟來拆解這個原理：
#
# ### 1. 陽光其實是彩色的
# 我們平常看到的太陽光看似是白色的，但其實它包含了彩虹的七彩顏色（紅、橙、黃、綠、藍、靛、紫）。這些光以「波」的形式傳播：
# *   **紅光、黃光**的波長較**長**。
# *   **藍光、紫光**的波長較**短**。
#
# ### 2. 大氣層的「擋路石」
# 當太陽光穿過地球的大氣層時，會碰到大氣中的氣體分子（主要是氮氣和氧氣）。這些微小的氣體分子就像是道路上的小石頭。
#
# ### 3. 「瑞利散射」發生了
# 當光線碰到這些微小的氣體分子時，會發生碰撞並向四面八方散射：
# *   **波長較長的光（如紅光、黃光）**：因為波長很長，它們可以輕易地繞過這些微小的氣體分子，直接穿透大氣層直達地面。
# *   **波長較短的光（如藍光、紫光）**：因為波長很短，很容易撞上這些氣體分子，並被**瘋狂地朝各個方向散射**。
# 當我們抬頭看天空時，眼睛接收到的就是這些在大氣層中被到處散射的藍色光，所以天空看起來就是藍色的。
#
# ---
#
# ### 🤔 為什麼天空不是「紫色」的？
# 你可能會問：**紫光的波長比藍光更短，散射得更厲害，那為什麼天空不是紫色的？**
#
# 這有兩個主要原因：
# 1.  **太陽光的成分**：太陽放射出的光芒中，藍光的比例本來就比紫光多很多。
# 2.  **人類眼睛的構造**：人類眼睛的視網膜上有三種辨色細胞（錐狀細胞），分別對紅、綠、藍光最敏感。我們的眼睛對藍光的敏感度遠高於紫光。因此，大腦會自動把接收到的混合光線解讀為「明亮的藍色」。
#
# ---
#
# ### 💡 補充：為什麼傍晚的夕陽是紅色的？
# 黃昏時，太陽的角度很低，陽光必須穿過**比中午厚很多**的大氣層才能到達我們的眼睛。
# 在這個過程中，藍光在到達我們眼睛之前，就已經在半路被散射光了；只剩下波長最長、穿透力最強的**紅光和橙光**能成功到達我們的眼睛，所以夕陽和晚霞看起來就是紅通通的。
