# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以是藍色的，主要是因為一個物理現象，叫做**「瑞利散射」（Rayleigh scattering）**。
#
# 我們可以把這個過程拆解成三個簡單的步驟來理解：
#
# ### 1. 太陽光其實是「彩虹色」的
# 雖然太陽光看起來是白色的，但它其實包含了紅、橙、黃、綠、藍、靛、紫等所有顏色的光。
# 這些光以「波」的形式傳播：
# *   **紅色、黃色**的光：波長較**長**。
# *   **藍色、紫色**的光：波長較**短**。
#
# ### 2. 大氣層的「阻擋」
# 當太陽光穿過地球的大氣層時，會撞擊到大氣中的氣體分子（主要是氮氣和氧氣）。
# *   波長較**長**的光（如紅光、黃光）很有「穿透力」，可以直接穿過這些微小的氣體分子，直達地面。
# *   波長較**短**的光（如藍光、紫光）則很容易撞上這些氣體分子，並向四面八方**散射（彈開）**。這就是「瑞利散射」。
# *   因為藍光在空中被到處亂彈，填滿了整個天空，所以當我們抬頭看時，就會看到滿眼的藍色。
#
# ### 3. 為什麼天空不是「紫色」的？
# 既然紫光的波長比藍光更短、散射得更厲害，那為什麼天空不是紫色的呢？這有兩個原因：
# 1.  **太陽光的組成**：太陽放射出的光芒中，藍光的比例本來就比紫光多很多。
# 2.  **人類眼睛的構造**：人類視網膜上的感光細胞對於「藍色」比對「紫色」敏感得多。因此，即使天空有一些紫光，我們的眼睛和大腦也會自動把它過濾並解讀為藍色。
#
# ---
#
# ### 💡 延伸思考：為什麼傍晚的夕陽是紅色的？
# 在黃昏或清晨時，太陽角度很低，陽光必須穿過**比中午厚很多**的大氣層才能到達我們的眼睛。
# 在這段長途旅程中，絕大多數的藍光在半路就已經被散射光了，只剩下穿透力最強的**紅光和橙光**能夠到達我們的眼睛，所以夕陽看起來就是美麗的紅橘色。
