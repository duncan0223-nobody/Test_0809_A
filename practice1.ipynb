# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以是藍色的，主要是因為一個物理現象，叫做**「瑞利散射」（Rayleigh scattering）**。
#
# 我們可以把這個過程拆解成三個簡單的步驟來理解：
#
# ### 1. 太陽光其實是「彩虹色」的
# 雖然太陽光看起來是白色的，但它其實是由紅、橙、黃、綠、藍、靛、紫等所有顏色的光混合而成的。這些光以「波」的形式傳播：
# *   **紅色光**的波長最**長**。
# *   **藍色和紫色光**的波長最**短**。
#
# ### 2. 大氣層的「阻礙」
# 當太陽光穿過地球的大氣層時，會碰到大氣中的氣體分子（主要是氮氣和氧氣）。
# *   波長較長的紅光、黃光穿透力很強，能直接穿透這些氣體分子，直達地面。
# *   波長較短的**藍光**，遇到這些微小的氣體分子時，就會像彈珠碰到障礙物一樣，**被撞得向四面八方散射開來**。這種現象就是「瑞利散射」。
#
# 因為藍光在天空中到處亂飛，當我們抬頭看天空時，這些散射的藍光進入我們的眼睛，天空看起來就是藍色的。
#
# ---
#
# ### 💡 常見的疑問：為什麼天空不是「紫色」的？
# 紫光的波長比藍光更短，照理說散射得更厲害，天空為什麼不是紫色的？原因有兩個：
# 1.  **太陽光的組成**：太陽放射出的光芒中，藍光的比例本來就比紫光多很多。
# 2.  **人類眼睛的構造**：人類視網膜上的感光細胞，對藍色非常敏感，而對紫色的感光能力較差。大腦會自動把接收到的光線過濾、調和成我們所看到的蔚藍色。
#
# ### 額外知識：為什麼傍晚的天空是紅色的？
# 傍晚太陽下山時，陽光是斜射過來的，必須穿過**比中午厚上許多倍**的大氣層。這時候，藍光在半路就已經被散射光了，根本無法到達我們的眼睛；只有穿透力最強的紅光和黃光能穿透厚厚的大氣落入我們眼中，所以夕陽和晚霞才會呈現美麗的橙紅色。
