# %%
print ('hello world')
print ('='*10)
print (50)
print (50.3234)
# Out:
# hello world
# ...
# 50
# 50.3234

# %%
print ('test hello world')
print (True)
# Out:
# test hello world
# True

# %%
print("這是整數", 50)
print("這是浮點數", 50.5)
print("這是字串", 'robert')
print("這是布林值", True)
print("這是布林值", False)
# Out:
# 這是整數 50
# 這是浮點數 50.5
# 這是字串 robert
# 這是布林值 True
# 這是布林值 False
